# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/enriquebriceno/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
news_api_key = os.getenv("NEWSAPIKEY")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=news_api_key)
print(news_api_key)
# Out:
# 262b5dc5038f49ffb4d95de3e0aa3469

# %%
# Fetch the Bitcoin news articles
bitcoin_news_en = newsapi.get_everything(
    q="Bitcoin",
    language="en"
)

# %%
# Fetch the Ethereum news articles
ethereum_news_en = newsapi.get_everything(
    q="Ethereum",
    language="en"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
bitcoin_df = pd.DataFrame(bitcoin_sentiments)
bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Even in cyberspace, the Department of Justice ...  2022-02-17    0.7351
# 1  The couple would never flee from the country a...  2022-02-13   -0.3400
# 2  If Sundays Super Bowl ads are any indication, ...  2022-02-14    0.7783
# 3  The news of one of the biggest money launderin...  2022-02-12    0.5859
# 4  The confiscation of the Bitcoin that remained ...  2022-02-15    0.6486
#
#    positive  negative  neutral
# 0     0.147     0.000    0.853
# 1     0.057     0.118    0.825
# 2     0.163     0.000    0.837
# 3     0.124     0.000    0.876
# 4     0.146     0.000    0.854

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
ethereum_df = pd.DataFrame(ethereum_sentiments)
ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  In February, shit hit the fan in the usual way...  2022-03-01   -0.3182
# 1  Technical analysis isnt a perfect tool, but it...  2022-02-17   -0.2498
# 2  People in Colorado will be able to pay their s...  2022-02-16   -0.1027
# 3  Coinbase reported that the share of trading vo...  2022-02-25    0.6705
# 4  Illustration by James Bareham / The Verge\r\n\...  2022-02-26   -0.4588
#
#    positive  negative  neutral
# 0     0.059     0.093    0.848
# 1     0.000     0.059    0.941
# 2     0.000     0.036    0.964
# 3     0.188     0.000    0.812
# 4     0.000     0.083    0.917

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.106555   0.075800   0.046950   0.877250
# std     0.483892   0.050338   0.065909   0.065284
# min    -0.771300   0.000000   0.000000   0.739000
# 25%    -0.277550   0.047500   0.000000   0.835500
# 50%     0.102600   0.067500   0.000000   0.865000
# 75%     0.564525   0.109000   0.097750   0.931000
# max     0.778300   0.163000   0.187000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.138635   0.074300   0.033850   0.891850
# std     0.391072   0.080074   0.042274   0.090052
# min    -0.526700   0.000000   0.000000   0.692000
# 25%    -0.110175   0.000000   0.000000   0.841000
# 50%     0.000000   0.057500   0.000000   0.904500
# 75%     0.502100   0.130250   0.065000   0.958000
# max     0.772200   0.249000   0.115000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {'said', 'sent', 'found', 'including', 'today', 'announced', 'week', 'basically', 'ha', 'char','also', 'reutersdado'}

# %%
# Complete the tokenizer function
def tokenizer(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', article)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    return output

# %%
# Compile the list of lists of tokens for each Bitcoin article
btc_word_tokenized = []
for text in bitcoin_df.text:
    # Create a list of tokenized words for each article    
    words = []
    words = words + tokenizer(text)
    # append all lists of tokenized words for each article to the btc_word_tokenized list of lists
    btc_word_tokenized.append(words)
print(btc_word_tokenized)
# Out:
# [['even', 'cyberspace', 'department', 'justice', 'able', 'use', 'tried', 'true', 'investigative', 'technique', 'following', 'money', 'ms', 'monaco', 'led', 'u', 'al', 'capone', 'helped', 'u', 'dest'], ['couple', 'would', 'never', 'flee', 'country', 'risk', 'losing', 'access', 'ability', 'child', 'lawyer', 'wroteat', 'hearing', 'prosecutor', 'margaret', 'lynaugh', 'opposing', 'bail', 'f'], ['sundays', 'super', 'bowl', 'ad', 'indication', 'crypto', 'truly', 'arrived', 'mainstream', 'culture', 'didnt', 'catch', 'game', 'watch', 'ad', 'featuring', 'larry', 'david', 'lebron', 'james', 'q'], ['news', 'one', 'biggest', 'money', 'laundering', 'scheme', 'history', 'captivated', 'world', 'tuesday', 'much', 'crimewhich', 'involved', 'billion', 'bitcoin', 'yeah', 'big', 'dealbut'], ['confiscation', 'bitcoin', 'remained', 'mr', 'lichtensteins', 'wallet', 'feb', 'worth', 'roughly', 'billion', 'time', 'wa', 'justice', 'departments', 'largest', 'financial', 'seizure', 'ever', 'official'], ['bitcoin', 'wa', 'seen', 'many', 'libertarianleaning', 'fan', 'kind', 'doomsday', 'insurance', 'argues', 'columnist', 'new', 'york', 'times', 'form', 'digital', 'gold', 'would', 'source', 'stability'], ['feb', 'reuters', 'bitcoin', 'miner', 'feeling', 'heat', 'pain', 'rippling', 'downstream', 'pressure', 'pricesthe', 'cryptocurrencys', 'spectacular', 'rally', 'drew', 'thousand', 'entrant', 'mining'], ['march', 'reuters', 'bitcoin', 'leapt', 'since', 'russias', 'invasion', 'ukraine', 'bolstered', 'people', 'country', 'looking', 'store', 'move', 'money', 'anonymous', 'decentralised', 'cryptobitcoin', 'tradin'], ['whose', 'side', 'cryptocurrency', 'asked', 'satoshi', 'nakamoto', 'pseudonymous', 'person', 'person', 'created', 'bitcoin', 'platform', 'hethey', 'likely', 'would', 'rejected', 'question'], ['gettywelcome', 'nonfungible', 'tidbits', 'focus', 'russias', 'war', 'ukrainein', 'addition', 'uprooting', 'life', 'ukrainians', 'throwing', 'international', 'order', 'chaos', 'russian'], ['appeal', 'court', 'decided', 'shilling', 'unregistered', 'security', 'youtube', 'thing', 'letterillustration', 'alex', 'castro', 'vergethe', 'story', 'bitconnect', 'doesnt', 'include'], ['nurphotogettyas', 'russia', 'launched', 'invasion', 'home', 'country', 'last', 'thursday', 'ukranian', 'photographer', 'vitaliy', 'raskalov', 'world', 'away', 'mexico', 'city', 'spoke', 'telegr'], ['feb', 'reuters', 'bristling', 'tension', 'looming', 'law', 'europe', 'could', 'offer', 'clue', 'two', 'question', 'bitcoin', 'safehaven', 'asset', 'russia', 'emerge', 'crypto', 'superpowerthe', 'answer', 'th'], ['london', 'march', 'reuters', 'cryptocurrencies', 'close', 'headline', 'since', 'russia', 'invaded', 'ukraine', 'evervolatile', 'bitcoin', 'demand', 'russia', 'beyondhere', 'chart', 'l'], ['feb', 'welcome', 'home', 'realtime', 'coverage', 'market', 'brought', 'reuters', 'reporter', 'share', 'thought', 'u', 'marketsresearchthomsonreuterscombitcoin', 'exactly'], ['ukrainian', 'government', 'asking', 'donation', 'bitcoin', 'show', 'utility', 'cryptocurrency', 'positive', 'sign', 'market', 'veteran', 'strategist', 'tom', 'lee', 'saidukraine', 'government', 'accoun'], ['dont', 'expect', 'bitcoin', 'double', 'triple', 'price', 'anytime', 'soon', 'going', 'shark', 'tank', 'investor', 'kevin', 'olearys', 'predictionif', 'want', 'talk', 'bitcoin', 'going'], ['bitcoin', 'rallied', 'twoweek', 'high', 'tuesday', 'spite', 'turmoil', 'broader', 'market', 'thanks', 'surge', 'buying', 'russians', 'ukrainians', 'may', 'seeking', 'refuge', 'cryptocurrencies'], ['ullisummarylililaw', 'firmslilirelated', 'documentsliulthe', 'company', 'law', 'firm', 'name', 'shown', 'generated', 'automatically', 'based', 'text', 'article', 'improving'], ['san', 'salvador', 'feb', 'reuters', 'el', 'salvador', 'president', 'nayib', 'bukele', 'sunday', 'send', 'congress', 'proposal', 'grant', 'citizenship', 'foreigner', 'invest', 'central', 'american', 'country']]

# %%
bitcoin_df["tokens"]=btc_word_tokenized
bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Even in cyberspace, the Department of Justice ...  2022-02-17    0.7351
# 1  The couple would never flee from the country a...  2022-02-13   -0.3400
# 2  If Sundays Super Bowl ads are any indication, ...  2022-02-14    0.7783
# 3  The news of one of the biggest money launderin...  2022-02-12    0.5859
# 4  The confiscation of the Bitcoin that remained ...  2022-02-15    0.6486
#
#    positive  negative  neutral  \
# 0     0.147     0.000    0.853
# 1     0.057     0.118    0.825
# 2     0.163     0.000    0.837
# 3     0.124     0.000    0.876
# 4     0.146     0.000    0.854
#
#                                               tokens
# 0  [even, cyberspace, department, justice, able, ...
# 1  [couple, would, never, flee, country, risk, lo...
# 2  [sundays, super, bowl, ad, indication, crypto,...
# 3  [news, one, biggest, money, laundering, scheme...
# 4  [confiscation, bitcoin, remained, mr, lichtens...

# %%
# Compile the list of lists of tokens for each Ethereum article
eth_word_tokenized = []
for text in ethereum_df.text:
   # Create a list of tokenized words for each article 
    words = []
    words = words + tokenizer(text)
    # append all lists of tokenized words for each article to the eth_word_tokenized list of lists
    eth_word_tokenized.append(words)
print(eth_word_tokenized)
# Out:
# [['february', 'shit', 'hit', 'fan', 'usual', 'way', 'old', 'tweet', 'resurfaced', 'brantly', 'millegan', 'director', 'operation', 'ethereum', 'name', 'service', 'ens', 'web', 'business', 'written', 'following', 'may'], ['technical', 'analysis', 'isnt', 'perfect', 'tool', 'may', 'point', 'way', 'ethereumethereumethusd', 'continues', 'volatile', 'crypto', 'investment', 'crypto', 'volatile', 'nature', 'im', 'setting', 'apart'], ['people', 'colorado', 'able', 'pay', 'state', 'tax', 'cryptocurrency', 'middle', 'year', 'us', 'state', 'governor', 'revealedgov', 'jared', 'polis', 'laid', 'timing', 'move', 'longt'], ['coinbase', 'reported', 'share', 'trading', 'volume', 'ethereum', 'altcoins', 'increased', 'last', 'year', 'bitcoins', 'share', 'dropped', 'dramaticallybetween', 'ethereum', 'trading', 'volume'], ['illustration', 'james', 'bareham', 'verge', 'million', 'donated', 'far', 'million', 'cryptocurrency', 'donated', 'ukrainian', 'group', 'since', 'russia', 'attacked', 'c'], ['seems', 'cant', 'escape', 'metaversefrom', 'facebook', 'microsoft', 'seemingly', 'every', 'centralized', 'tech', 'firm', 'clambering', 'bandwagon', 'emerging', 'virtual', 'reality', 'puris'], ['last', 'night', 'twitter', 'itll', 'allow', 'user', 'tip', 'account', 'via', 'ethereumthis', 'social', 'network', 'second', 'crypto', 'announcement', 'two', 'month', 'enabled', 'nftbased', 'profile', 'picture', 'janu'], ['two', 'hour', 'long', 'wildly', 'popular', 'new', 'youtube', 'documentary', 'line', 'goes', 'problem', 'nfts', 'exhaustive', 'takedown', 'hot', 'new', 'investment', 'vehicle', 'everyone', 'waka', 'flacka', 'fla'], ['cryptocurrency', 'boom', 'past', 'year', 'helped', 'propel', 'newer', 'market', 'record', 'height', 'digital', 'collectible', 'known', 'nftsin', 'fact', 'total', 'nft', 'sale', 'volume', 'hit', 'billion', 'past'], ['version', 'article', 'wa', 'published', 'times', 'newsletter', 'metaverse', 'subscribe', 'weekly', 'guide', 'future', 'internet', 'find', 'past', 'issue', 'newsletter', 'herethe', 'ethe'], ['version', 'article', 'wa', 'published', 'times', 'newsletter', 'metaverse', 'subscribe', 'weekly', 'guide', 'future', 'internet', 'find', 'past', 'issue', 'newsletter', 'herelast', 'wee'], ['joe', 'biden', 'dipping', 'toe', 'crypto', 'wednesday', 'president', 'signed', 'firstofitskind', 'executive', 'order', 'outlining', 'path', 'regulation', 'cryptocurrencies', 'encouraging', 'federal', 'agency'], ['bitcoins', 'dominance', 'cryptocurrencies', 'dwindle', 'token', 'using', 'proofofstake', 'system', 'eat', 'away', 'market', 'share', 'ftxus', 'bos', 'brett', 'harrison', 'predictedbitcoins', 'grip', 'loosening', 'th'], ['cryptocurrency', 'boom', 'past', 'year', 'helped', 'propel', 'newer', 'market', 'record', 'height', 'digital', 'collectible', 'known', 'nftsin', 'fact', 'total', 'nft', 'sale', 'volume', 'hit', 'billion', 'past'], ['blockchain', 'technology', 'reach', 'true', 'mass', 'adoption', 'become', 'cheaper', 'efficient', 'low', 'transaction', 'throughput', 'popular', 'blockchains', 'notably', 'ethereum'], ['personal', 'finance', 'insider', 'writes', 'product', 'strategy', 'tip', 'help', 'make', 'smart', 'decision', 'money', 'may', 'receive', 'small', 'commission', 'partner', 'like', 'american', 'express'], ['kitco', 'news', 'escalating', 'russiaukraine', 'crisis', 'new', 'sanction', 'surging', 'oil', 'price', 'investor', 'fleeing', 'riskon', 'asset', 'crypto', 'space', 'getting', 'safehaven', 'appeal', 'back', 'peop'], ['ok', 'let', 'explain', 'string', 'emojis', 'url', 'entered', 'address', 'line', 'opera', 'browser', 'take', 'singer', 'keshas', 'website', 'opera', 'monday', 'enabled', 'emo'], ['personal', 'finance', 'insider', 'writes', 'product', 'strategy', 'tip', 'help', 'make', 'smart', 'decision', 'money', 'may', 'receive', 'small', 'commission', 'partner', 'like', 'american', 'express'], ['ukrainian', 'nonprofit', 'raised', 'bitcoin', 'worth', 'million', 'support', 'country', 'army', 'since', 'russia', 'attacked', 'according',  ...

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"]=eth_word_tokenized
ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  In February, shit hit the fan in the usual way...  2022-03-01   -0.3182
# 1  Technical analysis isnt a perfect tool, but it...  2022-02-17   -0.2498
# 2  People in Colorado will be able to pay their s...  2022-02-16   -0.1027
# 3  Coinbase reported that the share of trading vo...  2022-02-25    0.6705
# 4  Illustration by James Bareham / The Verge\r\n\...  2022-02-26   -0.4588
#
#    positive  negative  neutral  \
# 0     0.059     0.093    0.848
# 1     0.000     0.059    0.941
# 2     0.000     0.036    0.964
# 3     0.188     0.000    0.812
# 4     0.000     0.083    0.917
#
#                                               tokens
# 0  [february, shit, hit, fan, usual, way, old, tw...
# 1  [technical, analysis, isnt, perfect, tool, may...
# 2  [people, colorado, able, pay, state, tax, cryp...
# 3  [coinbase, reported, share, trading, volume, e...
# 4  [illustration, james, bareham, verge, million,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Create a flat list of Bitcoin tokenized words from a list of list
btc_flat_word_tokenized_list = [item for elem in btc_word_tokenized for item in elem]
print(btc_flat_word_tokenized_list)
# Out:
# ['even', 'cyberspace', 'department', 'justice', 'able', 'use', 'tried', 'true', 'investigative', 'technique', 'following', 'money', 'ms', 'monaco', 'led', 'u', 'al', 'capone', 'helped', 'u', 'dest', 'couple', 'would', 'never', 'flee', 'country', 'risk', 'losing', 'access', 'ability', 'child', 'lawyer', 'wroteat', 'hearing', 'prosecutor', 'margaret', 'lynaugh', 'opposing', 'bail', 'f', 'sundays', 'super', 'bowl', 'ad', 'indication', 'crypto', 'truly', 'arrived', 'mainstream', 'culture', 'didnt', 'catch', 'game', 'watch', 'ad', 'featuring', 'larry', 'david', 'lebron', 'james', 'q', 'news', 'one', 'biggest', 'money', 'laundering', 'scheme', 'history', 'captivated', 'world', 'tuesday', 'much', 'crimewhich', 'involved', 'billion', 'bitcoin', 'yeah', 'big', 'dealbut', 'confiscation', 'bitcoin', 'remained', 'mr', 'lichtensteins', 'wallet', 'feb', 'worth', 'roughly', 'billion', 'time', 'wa', 'justice', 'departments', 'largest', 'financial', 'seizure', 'ever', 'official', 'bitcoin', 'wa', 'seen', 'many', 'libertarianleaning', 'fan', 'kind', 'doomsday', 'insurance', 'argues', 'columnist', 'new', 'york', 'times', 'form', 'digital', 'gold', 'would', 'source', 'stability', 'feb', 'reuters', 'bitcoin', 'miner', 'feeling', 'heat', 'pain', 'rippling', 'downstream', 'pressure', 'pricesthe', 'cryptocurrencys', 'spectacular', 'rally', 'drew', 'thousand', 'entrant', 'mining', 'march', 'reuters', 'bitcoin', 'leapt', 'since', 'russias', 'invasion', 'ukraine', 'bolstered', 'people', 'country', 'looking', 'store', 'move', 'money', 'anonymous', 'decentralised', 'cryptobitcoin', 'tradin', 'whose', 'side', 'cryptocurrency', 'asked', 'satoshi', 'nakamoto', 'pseudonymous', 'person', 'person', 'created', 'bitcoin', 'platform', 'hethey', 'likely', 'would', 'rejected', 'question', 'gettywelcome', 'nonfungible', 'tidbits', 'focus', 'russias', 'war', 'ukrainein', 'addition', 'uprooting', 'life', 'ukrainians', 'throwing', 'international', 'order', 'chaos', 'russian', 'appeal', 'court', 'decided', 'shilling', 'unregistered', 'security', 'youtube', 'thing', 'letterillustration', 'alex', 'castro', 'vergethe', 'story', 'bitconnect', 'doesnt', 'include', 'nurphotogettyas', 'russia', 'launched', 'invasion', 'home', 'country', 'last', 'thursday', 'ukranian', 'photographer', 'vitaliy', 'raskalov', 'world', 'away', 'mexico', 'city', 'spoke', 'telegr', 'feb', 'reuters', 'bristling', 'tension', 'looming', 'law', 'europe', 'could', 'offer', 'clue', 'two', 'question', 'bitcoin', 'safehaven', 'asset', 'russia', 'emerge', 'crypto', 'superpowerthe', 'answer', 'th', 'london', 'march', 'reuters', 'cryptocurrencies', 'close', 'headline', 'since', 'russia', 'invaded', 'ukraine', 'evervolatile', 'bitcoin', 'demand', 'russia', 'beyondhere', 'chart', 'l', 'feb', 'welcome', 'home', 'realtime', 'coverage', 'market', 'brought', 'reuters', 'reporter', 'share', 'thought', 'u', 'marketsresearchthomsonreuterscombitcoin', 'exactly', 'ukrainian', 'government', 'asking', 'donation', 'bitcoin', 'show', 'utility', 'cryptocurrency', 'positive', 'sign', 'market', 'veteran', 'strategist', 'tom', 'lee', 'saidukraine', 'government', 'accoun', 'dont', 'expect', 'bitcoin', 'double', 'triple', 'price', 'anytime', 'soon', 'going', 'shark', 'tank', 'investor', 'kevin', 'olearys', 'predictionif', 'want', 'talk', 'bitcoin', 'going', 'bitcoin', 'rallied', 'twoweek', 'high', 'tuesday', 'spite', 'turmoil', 'broader', 'market', 'thanks', 'surge', 'buying', 'russians', 'ukrainians', 'may', 'seeking', 'refuge', 'cryptocurrencies', 'ullisummarylililaw', 'firmslilirelated', 'documentsliulthe', 'company', 'law', 'firm', 'name', 'shown', 'generated', 'automatically', 'based', 'text', 'article', 'improving', 'san', 'salvador', 'feb', 'reuters', 'el', 'salvador', 'president', 'nayib', 'bukele', 'sunday', 'send', 'congress', 'proposal', 'grant', 'citizenship', 'foreigner', 'invest', 'central', 'american', 'country']

# %%
# Generate the Bitcoin N-grams where N=2
btc_n_gram_counts = Counter(ngrams(btc_flat_word_tokenized_list, n=2))
print(dict(btc_n_gram_counts))
# Out:
# {('even', 'cyberspace'): 1, ('cyberspace', 'department'): 1, ('department', 'justice'): 1, ('justice', 'able'): 1, ('able', 'use'): 1, ('use', 'tried'): 1, ('tried', 'true'): 1, ('true', 'investigative'): 1, ('investigative', 'technique'): 1, ('technique', 'following'): 1, ('following', 'money'): 1, ('money', 'ms'): 1, ('ms', 'monaco'): 1, ('monaco', 'led'): 1, ('led', 'u'): 1, ('u', 'al'): 1, ('al', 'capone'): 1, ('capone', 'helped'): 1, ('helped', 'u'): 1, ('u', 'dest'): 1, ('dest', 'couple'): 1, ('couple', 'would'): 1, ('would', 'never'): 1, ('never', 'flee'): 1, ('flee', 'country'): 1, ('country', 'risk'): 1, ('risk', 'losing'): 1, ('losing', 'access'): 1, ('access', 'ability'): 1, ('ability', 'child'): 1, ('child', 'lawyer'): 1, ('lawyer', 'wroteat'): 1, ('wroteat', 'hearing'): 1, ('hearing', 'prosecutor'): 1, ('prosecutor', 'margaret'): 1, ('margaret', 'lynaugh'): 1, ('lynaugh', 'opposing'): 1, ('opposing', 'bail'): 1, ('bail', 'f'): 1, ('f', 'sundays'): 1, ('sundays', 'super'): 1, ('super', 'bowl'): 1, ('bowl', 'ad'): 1, ('ad', 'indication'): 1, ('indication', 'crypto'): 1, ('crypto', 'truly'): 1, ('truly', 'arrived'): 1, ('arrived', 'mainstream'): 1, ('mainstream', 'culture'): 1, ('culture', 'didnt'): 1, ('didnt', 'catch'): 1, ('catch', 'game'): 1, ('game', 'watch'): 1, ('watch', 'ad'): 1, ('ad', 'featuring'): 1, ('featuring', 'larry'): 1, ('larry', 'david'): 1, ('david', 'lebron'): 1, ('lebron', 'james'): 1, ('james', 'q'): 1, ('q', 'news'): 1, ('news', 'one'): 1, ('one', 'biggest'): 1, ('biggest', 'money'): 1, ('money', 'laundering'): 1, ('laundering', 'scheme'): 1, ('scheme', 'history'): 1, ('history', 'captivated'): 1, ('captivated', 'world'): 1, ('world', 'tuesday'): 1, ('tuesday', 'much'): 1, ('much', 'crimewhich'): 1, ('crimewhich', 'involved'): 1, ('involved', 'billion'): 1, ('billion', 'bitcoin'): 1, ('bitcoin', 'yeah'): 1, ('yeah', 'big'): 1, ('big', 'dealbut'): 1, ('dealbut', 'confiscation'): 1, ('confiscation', 'bitcoin'): 1, ('bitcoin', 'remained'): 1, ('remained', 'mr'): 1, ('mr', 'lichtensteins'): 1, ('lichtensteins', 'wallet'): 1, ('wallet', 'feb'): 1, ('feb', 'worth'): 1, ('worth', 'roughly'): 1, ('roughly', 'billion'): 1, ('billion', 'time'): 1, ('time', 'wa'): 1, ('wa', 'justice'): 1, ('justice', 'departments'): 1, ('departments', 'largest'): 1, ('largest', 'financial'): 1, ('financial', 'seizure'): 1, ('seizure', 'ever'): 1, ('ever', 'official'): 1, ('official', 'bitcoin'): 1, ('bitcoin', 'wa'): 1, ('wa', 'seen'): 1, ('seen', 'many'): 1, ('many', 'libertarianleaning'): 1, ('libertarianleaning', 'fan'): 1, ('fan', 'kind'): 1, ('kind', 'doomsday'): 1, ('doomsday', 'insurance'): 1, ('insurance', 'argues'): 1, ('argues', 'columnist'): 1, ('columnist', 'new'): 1, ('new', 'york'): 1, ('york', 'times'): 1, ('times', 'form'): 1, ('form', 'digital'): 1, ('digital', 'gold'): 1, ('gold', 'would'): 1, ('would', 'source'): 1, ('source', 'stability'): 1, ('stability', 'feb'): 1, ('feb', 'reuters'): 3, ('reuters', 'bitcoin'): 2, ('bitcoin', 'miner'): 1, ('miner', 'feeling'): 1, ('feeling', 'heat'): 1, ('heat', 'pain'): 1, ('pain', 'rippling'): 1, ('rippling', 'downstream'): 1, ('downstream', 'pressure'): 1, ('pressure', 'pricesthe'): 1, ('pricesthe', 'cryptocurrencys'): 1, ('cryptocurrencys', 'spectacular'): 1, ('spectacular', 'rally'): 1, ('rally', 'drew'): 1, ('drew', 'thousand'): 1, ('thousand', 'entrant'): 1, ('entrant', 'mining'): 1, ('mining', 'march'): 1, ('march', 'reuters'): 2, ('bitcoin', 'leapt'): 1, ('leapt', 'since'): 1, ('since', 'russias'): 1, ('russias', 'invasion'): 1, ('invasion', 'ukraine'): 1, ('ukraine', 'bolstered'): 1, ('bolstered', 'people'): 1, ('people', 'country'): 1, ('country', 'looking'): 1, ('looking', 'store'): 1, ('store', 'move'): 1, ('move', 'money'): 1, ('money', 'anonymous'): 1, ('anonymous', 'decentralised'): 1, ('decentralised', 'cryptobitcoin'): 1, ('cryptobitcoin', 'tradin'): 1, ('tradin', 'whose'): 1, ('whose', 'side'): 1, ('side', 'cryptocurrency'): 1, ('cryptocurrency',  ...

# %%
eth_flat_word_tokenized_list = [item for elem in eth_word_tokenized for item in elem]
print(eth_flat_word_tokenized_list)
# Out:
# ['february', 'shit', 'hit', 'fan', 'usual', 'way', 'old', 'tweet', 'resurfaced', 'brantly', 'millegan', 'director', 'operation', 'ethereum', 'name', 'service', 'ens', 'web', 'business', 'written', 'following', 'may', 'technical', 'analysis', 'isnt', 'perfect', 'tool', 'may', 'point', 'way', 'ethereumethereumethusd', 'continues', 'volatile', 'crypto', 'investment', 'crypto', 'volatile', 'nature', 'im', 'setting', 'apart', 'people', 'colorado', 'able', 'pay', 'state', 'tax', 'cryptocurrency', 'middle', 'year', 'us', 'state', 'governor', 'revealedgov', 'jared', 'polis', 'laid', 'timing', 'move', 'longt', 'coinbase', 'reported', 'share', 'trading', 'volume', 'ethereum', 'altcoins', 'increased', 'last', 'year', 'bitcoins', 'share', 'dropped', 'dramaticallybetween', 'ethereum', 'trading', 'volume', 'illustration', 'james', 'bareham', 'verge', 'million', 'donated', 'far', 'million', 'cryptocurrency', 'donated', 'ukrainian', 'group', 'since', 'russia', 'attacked', 'c', 'seems', 'cant', 'escape', 'metaversefrom', 'facebook', 'microsoft', 'seemingly', 'every', 'centralized', 'tech', 'firm', 'clambering', 'bandwagon', 'emerging', 'virtual', 'reality', 'puris', 'last', 'night', 'twitter', 'itll', 'allow', 'user', 'tip', 'account', 'via', 'ethereumthis', 'social', 'network', 'second', 'crypto', 'announcement', 'two', 'month', 'enabled', 'nftbased', 'profile', 'picture', 'janu', 'two', 'hour', 'long', 'wildly', 'popular', 'new', 'youtube', 'documentary', 'line', 'goes', 'problem', 'nfts', 'exhaustive', 'takedown', 'hot', 'new', 'investment', 'vehicle', 'everyone', 'waka', 'flacka', 'fla', 'cryptocurrency', 'boom', 'past', 'year', 'helped', 'propel', 'newer', 'market', 'record', 'height', 'digital', 'collectible', 'known', 'nftsin', 'fact', 'total', 'nft', 'sale', 'volume', 'hit', 'billion', 'past', 'version', 'article', 'wa', 'published', 'times', 'newsletter', 'metaverse', 'subscribe', 'weekly', 'guide', 'future', 'internet', 'find', 'past', 'issue', 'newsletter', 'herethe', 'ethe', 'version', 'article', 'wa', 'published', 'times', 'newsletter', 'metaverse', 'subscribe', 'weekly', 'guide', 'future', 'internet', 'find', 'past', 'issue', 'newsletter', 'herelast', 'wee', 'joe', 'biden', 'dipping', 'toe', 'crypto', 'wednesday', 'president', 'signed', 'firstofitskind', 'executive', 'order', 'outlining', 'path', 'regulation', 'cryptocurrencies', 'encouraging', 'federal', 'agency', 'bitcoins', 'dominance', 'cryptocurrencies', 'dwindle', 'token', 'using', 'proofofstake', 'system', 'eat', 'away', 'market', 'share', 'ftxus', 'bos', 'brett', 'harrison', 'predictedbitcoins', 'grip', 'loosening', 'th', 'cryptocurrency', 'boom', 'past', 'year', 'helped', 'propel', 'newer', 'market', 'record', 'height', 'digital', 'collectible', 'known', 'nftsin', 'fact', 'total', 'nft', 'sale', 'volume', 'hit', 'billion', 'past', 'blockchain', 'technology', 'reach', 'true', 'mass', 'adoption', 'become', 'cheaper', 'efficient', 'low', 'transaction', 'throughput', 'popular', 'blockchains', 'notably', 'ethereum', 'personal', 'finance', 'insider', 'writes', 'product', 'strategy', 'tip', 'help', 'make', 'smart', 'decision', 'money', 'may', 'receive', 'small', 'commission', 'partner', 'like', 'american', 'express', 'kitco', 'news', 'escalating', 'russiaukraine', 'crisis', 'new', 'sanction', 'surging', 'oil', 'price', 'investor', 'fleeing', 'riskon', 'asset', 'crypto', 'space', 'getting', 'safehaven', 'appeal', 'back', 'peop', 'ok', 'let', 'explain', 'string', 'emojis', 'url', 'entered', 'address', 'line', 'opera', 'browser', 'take', 'singer', 'keshas', 'website', 'opera', 'monday', 'enabled', 'emo', 'personal', 'finance', 'insider', 'writes', 'product', 'strategy', 'tip', 'help', 'make', 'smart', 'decision', 'money', 'may', 'receive', 'small', 'commission', 'partner', 'like', 'american', 'express', 'ukrainian', 'nonprofit', 'raised', 'bitcoin', 'worth', 'million', 'support', 'country', 'army', 'since', 'russia', 'attacked', 'according', 'blockchain', 'analytics', 'company', ' ...

# %%
# Generate the Ethereum N-grams where N=2
eth_n_gram_counts = Counter(ngrams(eth_flat_word_tokenized_list, n=2))
print(dict(eth_n_gram_counts))
# Out:
# {('february', 'shit'): 1, ('shit', 'hit'): 1, ('hit', 'fan'): 1, ('fan', 'usual'): 1, ('usual', 'way'): 1, ('way', 'old'): 1, ('old', 'tweet'): 1, ('tweet', 'resurfaced'): 1, ('resurfaced', 'brantly'): 1, ('brantly', 'millegan'): 1, ('millegan', 'director'): 1, ('director', 'operation'): 1, ('operation', 'ethereum'): 1, ('ethereum', 'name'): 1, ('name', 'service'): 1, ('service', 'ens'): 1, ('ens', 'web'): 1, ('web', 'business'): 1, ('business', 'written'): 1, ('written', 'following'): 1, ('following', 'may'): 1, ('may', 'technical'): 1, ('technical', 'analysis'): 1, ('analysis', 'isnt'): 1, ('isnt', 'perfect'): 1, ('perfect', 'tool'): 1, ('tool', 'may'): 1, ('may', 'point'): 1, ('point', 'way'): 1, ('way', 'ethereumethereumethusd'): 1, ('ethereumethereumethusd', 'continues'): 1, ('continues', 'volatile'): 1, ('volatile', 'crypto'): 1, ('crypto', 'investment'): 1, ('investment', 'crypto'): 1, ('crypto', 'volatile'): 1, ('volatile', 'nature'): 1, ('nature', 'im'): 1, ('im', 'setting'): 1, ('setting', 'apart'): 1, ('apart', 'people'): 1, ('people', 'colorado'): 1, ('colorado', 'able'): 1, ('able', 'pay'): 1, ('pay', 'state'): 1, ('state', 'tax'): 1, ('tax', 'cryptocurrency'): 1, ('cryptocurrency', 'middle'): 1, ('middle', 'year'): 1, ('year', 'us'): 1, ('us', 'state'): 1, ('state', 'governor'): 1, ('governor', 'revealedgov'): 1, ('revealedgov', 'jared'): 1, ('jared', 'polis'): 1, ('polis', 'laid'): 1, ('laid', 'timing'): 1, ('timing', 'move'): 1, ('move', 'longt'): 1, ('longt', 'coinbase'): 1, ('coinbase', 'reported'): 1, ('reported', 'share'): 1, ('share', 'trading'): 1, ('trading', 'volume'): 2, ('volume', 'ethereum'): 1, ('ethereum', 'altcoins'): 1, ('altcoins', 'increased'): 1, ('increased', 'last'): 1, ('last', 'year'): 1, ('year', 'bitcoins'): 1, ('bitcoins', 'share'): 1, ('share', 'dropped'): 1, ('dropped', 'dramaticallybetween'): 1, ('dramaticallybetween', 'ethereum'): 1, ('ethereum', 'trading'): 1, ('volume', 'illustration'): 1, ('illustration', 'james'): 1, ('james', 'bareham'): 1, ('bareham', 'verge'): 1, ('verge', 'million'): 1, ('million', 'donated'): 1, ('donated', 'far'): 1, ('far', 'million'): 1, ('million', 'cryptocurrency'): 1, ('cryptocurrency', 'donated'): 1, ('donated', 'ukrainian'): 1, ('ukrainian', 'group'): 1, ('group', 'since'): 1, ('since', 'russia'): 2, ('russia', 'attacked'): 2, ('attacked', 'c'): 1, ('c', 'seems'): 1, ('seems', 'cant'): 1, ('cant', 'escape'): 1, ('escape', 'metaversefrom'): 1, ('metaversefrom', 'facebook'): 1, ('facebook', 'microsoft'): 1, ('microsoft', 'seemingly'): 1, ('seemingly', 'every'): 1, ('every', 'centralized'): 1, ('centralized', 'tech'): 1, ('tech', 'firm'): 1, ('firm', 'clambering'): 1, ('clambering', 'bandwagon'): 1, ('bandwagon', 'emerging'): 1, ('emerging', 'virtual'): 1, ('virtual', 'reality'): 1, ('reality', 'puris'): 1, ('puris', 'last'): 1, ('last', 'night'): 1, ('night', 'twitter'): 1, ('twitter', 'itll'): 1, ('itll', 'allow'): 1, ('allow', 'user'): 1, ('user', 'tip'): 1, ('tip', 'account'): 1, ('account', 'via'): 1, ('via', 'ethereumthis'): 1, ('ethereumthis', 'social'): 1, ('social', 'network'): 1, ('network', 'second'): 1, ('second', 'crypto'): 1, ('crypto', 'announcement'): 1, ('announcement', 'two'): 1, ('two', 'month'): 1, ('month', 'enabled'): 1, ('enabled', 'nftbased'): 1, ('nftbased', 'profile'): 1, ('profile', 'picture'): 1, ('picture', 'janu'): 1, ('janu', 'two'): 1, ('two', 'hour'): 1, ('hour', 'long'): 1, ('long', 'wildly'): 1, ('wildly', 'popular'): 1, ('popular', 'new'): 1, ('new', 'youtube'): 1, ('youtube', 'documentary'): 1, ('documentary', 'line'): 1, ('line', 'goes'): 1, ('goes', 'problem'): 1, ('problem', 'nfts'): 1, ('nfts', 'exhaustive'): 1, ('exhaustive', 'takedown'): 1, ('takedown', 'hot'): 1, ('hot', 'new'): 1, ('new', 'investment'): 1, ('investment', 'vehicle'): 1, ('vehicle', 'everyone'): 1, ('everyone', 'waka'): 1, ('waka', 'flacka'): 1, ('flacka', 'fla'): 1, ('fla', 'cryptocurrency'): 1, ('cryptocurrency', 'boom'): 2, ('boom', 'past') ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_counter(coin_token_list): 
    top_10 = dict(Counter(coin_token_list).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
# Use token_count to get the top 10 words for Bitcoin
token_counter(btc_flat_word_tokenized_list)
# Out:
#       word  count
# 0  bitcoin     12
# 1  reuters      6
# 2      feb      5
# 3  country      4
# 4   russia      4
# 5    money      3
# 6        u      3
# 7    would      3
# 8   market      3
# 9  justice      2

# %%
# Use token_count to get the top 10 words for Ethereum
token_counter(eth_flat_word_tokenized_list)
# Out:
#              word  count
# 0            past      6
# 1          crypto      5
# 2        ethereum      4
# 3             may      4
# 4  cryptocurrency      4
# 5            year      4
# 6          volume      4
# 7      newsletter      4
# 8             hit      3
# 9           share      3

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Convert a list of tokens into a single string of tokens
btc_big_string = ' '.join([str(elem) for elem in btc_flat_word_tokenized_list ])
print(btc_big_string)
# Out:
# even cyberspace department justice able use tried true investigative technique following money ms monaco led u al capone helped u dest couple would never flee country risk losing access ability child lawyer wroteat hearing prosecutor margaret lynaugh opposing bail f sundays super bowl ad indication crypto truly arrived mainstream culture didnt catch game watch ad featuring larry david lebron james q news one biggest money laundering scheme history captivated world tuesday much crimewhich involved billion bitcoin yeah big dealbut confiscation bitcoin remained mr lichtensteins wallet feb worth roughly billion time wa justice departments largest financial seizure ever official bitcoin wa seen many libertarianleaning fan kind doomsday insurance argues columnist new york times form digital gold would source stability feb reuters bitcoin miner feeling heat pain rippling downstream pressure pricesthe cryptocurrencys spectacular rally drew thousand entrant mining march reuters bitcoin leapt since russias invasion ukraine bolstered people country looking store move money anonymous decentralised cryptobitcoin tradin whose side cryptocurrency asked satoshi nakamoto pseudonymous person person created bitcoin platform hethey likely would rejected question gettywelcome nonfungible tidbits focus russias war ukrainein addition uprooting life ukrainians throwing international order chaos russian appeal court decided shilling unregistered security youtube thing letterillustration alex castro vergethe story bitconnect doesnt include nurphotogettyas russia launched invasion home country last thursday ukranian photographer vitaliy raskalov world away mexico city spoke telegr feb reuters bristling tension looming law europe could offer clue two question bitcoin safehaven asset russia emerge crypto superpowerthe answer th london march reuters cryptocurrencies close headline since russia invaded ukraine evervolatile bitcoin demand russia beyondhere chart l feb welcome home realtime coverage market brought reuters reporter share thought u marketsresearchthomsonreuterscombitcoin exactly ukrainian government asking donation bitcoin show utility cryptocurrency positive sign market veteran strategist tom lee saidukraine government accoun dont expect bitcoin double triple price anytime soon going shark tank investor kevin olearys predictionif want talk bitcoin going bitcoin rallied twoweek high tuesday spite turmoil broader market thanks surge buying russians ukrainians may seeking refuge cryptocurrencies ullisummarylililaw firmslilirelated documentsliulthe company law firm name shown generated automatically based text article improving san salvador feb reuters el salvador president nayib bukele sunday send congress proposal grant citizenship foreigner invest central american country

# %%
# Generate the Bitcoin word cloud
btc_wc = WordCloud().generate(btc_big_string)
plt.imshow(btc_wc)

# %%
eth_big_string = ' '.join([str(elem) for elem in eth_flat_word_tokenized_list ])
print(eth_big_string)
# Out:
# february shit hit fan usual way old tweet resurfaced brantly millegan director operation ethereum name service ens web business written following may technical analysis isnt perfect tool may point way ethereumethereumethusd continues volatile crypto investment crypto volatile nature im setting apart people colorado able pay state tax cryptocurrency middle year us state governor revealedgov jared polis laid timing move longt coinbase reported share trading volume ethereum altcoins increased last year bitcoins share dropped dramaticallybetween ethereum trading volume illustration james bareham verge million donated far million cryptocurrency donated ukrainian group since russia attacked c seems cant escape metaversefrom facebook microsoft seemingly every centralized tech firm clambering bandwagon emerging virtual reality puris last night twitter itll allow user tip account via ethereumthis social network second crypto announcement two month enabled nftbased profile picture janu two hour long wildly popular new youtube documentary line goes problem nfts exhaustive takedown hot new investment vehicle everyone waka flacka fla cryptocurrency boom past year helped propel newer market record height digital collectible known nftsin fact total nft sale volume hit billion past version article wa published times newsletter metaverse subscribe weekly guide future internet find past issue newsletter herethe ethe version article wa published times newsletter metaverse subscribe weekly guide future internet find past issue newsletter herelast wee joe biden dipping toe crypto wednesday president signed firstofitskind executive order outlining path regulation cryptocurrencies encouraging federal agency bitcoins dominance cryptocurrencies dwindle token using proofofstake system eat away market share ftxus bos brett harrison predictedbitcoins grip loosening th cryptocurrency boom past year helped propel newer market record height digital collectible known nftsin fact total nft sale volume hit billion past blockchain technology reach true mass adoption become cheaper efficient low transaction throughput popular blockchains notably ethereum personal finance insider writes product strategy tip help make smart decision money may receive small commission partner like american express kitco news escalating russiaukraine crisis new sanction surging oil price investor fleeing riskon asset crypto space getting safehaven appeal back peop ok let explain string emojis url entered address line opera browser take singer keshas website opera monday enabled emo personal finance insider writes product strategy tip help make smart decision money may receive small commission partner like american express ukrainian nonprofit raised bitcoin worth million support country army since russia attacked according blockchain analytics company ellipticcome back alive charita

# %%
# Generate the Ethereum word cloud
eth_wc = WordCloud().generate(eth_big_string)
plt.imshow(eth_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: setuptools in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: jinja2 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: importlib-metadata in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/enriquebriceno/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = []
for text in bitcoin_df.text:
    btc_text.append(text)
    
# Convert a list of texts into a single string of texts   
btc_text_string = ' '.join([str(elem) for elem in btc_text])
print(btc_text_string)
# Out:
# Even in cyberspace, the Department of Justice is able to use a tried and true investigative technique, following the money, Ms. Monaco said. Its what led us to Al Capone in the 30s. It helped us dest… [+1176 chars] The couple would never flee from the country at the risk of losing access to their ability to have children, the lawyer wrote.
# At the hearing, a prosecutor, Margaret Lynaugh, said in opposing bail f… [+1600 chars] If Sundays Super Bowl ads are any indication, crypto has truly arrived in mainstream culture. And if you didnt catch the game, you can watch the ads here, featuring Larry David, LeBron James, and a Q… [+3454 chars] The news of one of the biggest money laundering schemes in history captivated the world on Tuesday, not so much because of the crimewhich involved $4.5 billion in bitcoin and is, yeah, a big dealbut … [+1948 chars] The confiscation of the Bitcoin that remained in Mr. Lichtensteins wallet on Feb. 1, worth roughly $3.6 billion at the time, was the Justice Departments largest financial seizure ever, officials have… [+1442 chars] "Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the New York Times, "a form of 'digital gold' that would be a source of stability as … [+3914 chars] Feb 22 (Reuters) - Bitcoin miners are feeling the heat - and the pain's rippling downstream to pressure prices.
# The cryptocurrency's spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars] March 1 (Reuters) - Bitcoin has leapt since Russia's invasion of Ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.
# Bitcoin tradin… [+3955 chars] Whose side is cryptocurrency on? If you had asked Satoshi Nakamoto, the pseudonymous person (or persons) who created the Bitcoin platform in 2008, he/they likely would have rejected the question. The… [+3643 chars] Getty
# Welcome to Nonfungible Tidbits. Our focus this week: Russia's war in Ukraine.
# In addition to uprooting the lives of Ukrainians and throwing the international order into chaos, the Russian in… [+3275 chars] An appeals court decided shilling for an unregistered security on YouTube is the same thing as doing it in a letter.
# Illustration by Alex Castro / The Verge
# The story of BitConnect doesnt include a… [+3046 chars] Nurphoto/Getty
# As Russia launched an invasion into his home country last Thursday, Ukranian photographer Vitaliy Raskalov found himself a world away in Mexico City. When I spoke with him over Telegr… [+7815 chars] Feb 15 (Reuters) - Bristling tensions and looming laws in Europe could offer clues to two questions: Can bitcoin be a safe-haven asset? And can Russia emerge as a crypto superpower?
# The answer to th… [+4123 chars] LONDON, March 4 (Reuters) - Cryptocurrencies have been close to the headlines since Russia invaded Ukraine, with the ever-volatile bitcoin in demand in Russia and beyond.
# Here are some charts that l… [+3634 chars] Feb 24 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com
# BITCOIN, NOT EXACTLY A … [+6882 chars] The Ukrainian government asking for donations in bitcoin shows the utility of the cryptocurrency and is a positive sign for the market, veteran strategist Tom Lee has said.
# Ukraine government accoun… [+1750 chars] Don't expect bitcoin to double or triple in price anytime soon, going by "Shark Tank" investor Kevin O'Leary's prediction.
# "If you want to talk about bitcoin going to $100,000, $200,000, $300,000, i… [+2200 chars] Bitcoin rallied to a two-week high on Tuesday in spite of the turmoil on the broader markets, thanks to a surge in buying by Russians and Ukrainians who may be seeking refuge in cryptocurrencies as t… [+2894 chars] <ul><li>
# Summary</li><li>
# Law firms</li><li>
# Related documents</li></ul>
# The company and law firm names shown above are generated automatically based on the text of the article. We are improving … [+2414 chars] SAN SALVADOR, Feb 20 (Reuters) - El Salvador President Nayib Bukele on Sunday said he will send Congress a proposal to grant citizenship to foreigners who invest in the Central American country as we… [+1144 chars]

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_text_string)

# Add a title to the document
btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even in cyberspace,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Justice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is able to use a tried and true investigative technique, following the money, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monaco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Its what led us to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Al Capone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br>At the hearing, a prosecutor,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Margaret Lynaugh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , said in opposing bail f… [+1600 chars] If
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sundays Super Bowl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  ads are any indication, crypto has truly arrived in mainstream culture. And if you didnt catch the game, you can watch the ads here, featuring
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry David
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LeBron James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and a Q… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3454
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chars] The news of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the biggest money laundering schemes in history captivated the world on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , not so much because of the crimewhich involved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $4.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in bitcoin and is, yeah, a big dealbut … [+1948 chars] The confiscation of the Bitcoin that remained in Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lichtensteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wallet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb. 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $3.6 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at the time, was the Justice Departments largest financial seizure ever, officials have… [+1442 chars] &quot;Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance,&quot; argues a columnist in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;a form of 'digital gold' that would be a source of stability as … [+3914 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb 22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The cryptocurrency's spectacular rally in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  drew
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of entrants into mining,… [+4196 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin has leapt since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's invasion of
# <mark class="entity" style="background:

# %%
# List all Entities
btc_entities = [ent.text for ent in btc_doc.ents if ent.label_ in ['GPE', 'ORG']]
print(btc_entities)
# Out:
# ['the Department of Justice', '+3454', 'the New York Times', 'Reuters', 'Reuters', 'Russia', 'Ukraine', 'Getty\r\nWelcome to', 'Russia', 'Ukraine', 'YouTube', 'Verge', 'BitConnect', 'Nurphoto/Getty', 'Russia', 'Mexico City', 'Telegr', 'Reuters', 'Russia', 'LONDON', 'Reuters', 'Russia', 'Ukraine', 'Russia', 'Reuters', 'Ukraine', 'documents</li></ul', 'SAN SALVADOR', 'Reuters', 'El Salvador', 'Congress']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = []
for text in ethereum_df.text:
    eth_text.append(text)
eth_text_string = ' '.join([str(elem) for elem in eth_text])
print(eth_text_string)
# Out:
# In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars] Technical analysis isnt a perfect tool, but it may point the way for Ethereum
# Ethereum (ETH-USD
# ) continues to be a volatile crypto investment. Crypto is volatile by nature Im not setting it apart … [+3612 chars] People in Colorado will be able to pay their state taxes in cryptocurrency by the middle of this year, the US state's governor has revealed.
# Gov. Jared Polis laid out the timing of the move, a longt… [+2206 chars] Coinbase reported that the share of trading volume for ethereum and other altcoins increased last year, while bitcoin's share dropped dramatically.
# Between 2020 and 2021, ethereum trading volume in… [+1187 chars] Illustration by James Bareham / The Verge
#
#
#
#
#  More than $15 million has been donated so far More than $15 million in cryptocurrency has been donated to Ukrainian groups since Russia attacked the c… [+7442 chars] It seems that in 2022, you cant escape from the metaverse. From Facebook to Microsoft, seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars] Last night, Twitter announced itll allow users to tip accounts via Ethereum.
# This is the social networks second crypto announcement in two months, after it enabled NFT-based profile pictures in Janu… [+5114 chars] At over two hours long, the wildly popular new YouTube documentary  "Line Goes Up The Problem With NFTs" is an exhaustive takedown of the hot new investment vehicle that everyone from Waka Flacka Fla… [+2929 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.
# In fact, total NFT sales volume hit $23 billion over the past… [+2680 chars] A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.
# The Ethe… [+7320 chars] A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.
# Last wee… [+7988 chars] Joe Biden is dipping his toes into crypto. On Wednesday, the president signed a first-of-its-kind executive order outlining a path to regulation of cryptocurrencies and encouraging federal agencies t… [+2590 chars] Bitcoin's dominance in cryptocurrencies will dwindle as tokens using a proof-of-stake system eat away at its market share, FTX.US boss Brett Harrison has predicted.
# Bitcoin's grip is loosening as th… [+3022 chars] The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.
# In fact, total NFT sales volume hit $23 billion over the past… [+2633 chars] If blockchain technology is to reach true mass adoption, it will have to become cheaper and more efficient. Low transaction throughput on some of the most popular blockchains, most notably Ethereum, … [+1852 chars] Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+6262 chars] (Kitco News) The escalating Russia-Ukraine crisis, new sanctions, and surging oil prices have investors fleeing risk-on assets. And the crypto space is getting its safe-haven appeal back as more peop… [+3790 chars] .
# OK, let me explain. That string of emojis is a URL that, when entered into the address line in the Opera browser, takes you to singer Keshas website.
# Opera said on Monday that it had enabled emo… [+2601 chars] Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5248 chars] A Ukrainian nonprofit has raised bitcoin worth more than $4 million to support the country's army since Russia attacked, according to blockchain analytics company Elliptic.
# Come Back Alive a charita… [+2415 chars]

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text_string)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a web3 business, had written the following in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+3096 chars] Technical analysis isnt a perfect tool, but it may point the way for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Ethereum (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH-USD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>) continues to be a volatile crypto investment.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is volatile by nature Im not setting it apart … [+3612 chars] People in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be able to pay their state taxes in cryptocurrency by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the middle of this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Gov.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jared Polis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  laid out the timing of the move, a longt… [+2206 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reported that the share of trading volume for ethereum and other altcoins increased
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Between 2020 and 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ethereum trading volume in… [+1187 chars] Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Bareham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br> </br></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  has been donated so far
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency has been donated to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukrainian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  groups since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  attacked the c… [+7442 chars] It seems that in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , you cant escape from the metaverse. From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last nigh

# %%
# List all Entities
eth_entities = [ent.text for ent in eth_doc.ents if ent.label_ in ['GPE', 'ORG']]
print(eth_entities)
# Out:
# ['Ethereum Name Service', 'ENS', 'Ethereum', 'ETH-USD', 'Colorado', 'US', 'Ukrainian', 'Russia', 'Facebook', 'Microsoft', 'Ethereum', 'NFT', 'YouTube', 'Waka Flacka Fla', 'NFT', 'TIME', 'TIME', 'NFT', 'Ethereum', 'American Express', 'Russia', 'Ukraine', 'Opera', 'Opera', 'American Express', 'Russia']

# %% [markdown]
# ---
